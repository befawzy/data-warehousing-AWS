# %%
# %load_ext sql

# %%
# username = 'beshoy'
# password = 'beshoySubiyah241050'
# host=   
# %sql postgresql://{username}:{password}@{host}:{port}/{database}
# %sql SELECT * FROM '/home/befawzy/projects/DE_nanodegree/data_warehousing/project/data/2018/11/2018-11-01-events.json';
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
from pyspark.sql import SparkSession

spark =SparkSession.builder.appName("redshift_star_schema_tester").getOrCreate()
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 24/01/05 17:56:33 WARN Utils: Your hostname, LAPTOP-NHUPUQII resolves to a loopback address: 127.0.1.1; using 192.168.60.173 instead (on interface eth0)
# 24/01/05 17:56:33 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/01/05 17:56:33 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
#load events_data
events_data = spark.read\
    .json("/home/befawzy/projects/DE_nanodegree/data_warehousing/project/data/2018/*/*")
events_PATH_data = spark.read\
    .json("/home/befawzy/projects/DE_nanodegree/data_warehousing/project/data/log_json_path.json")

# %%
events_data.show()
# Out:
# +--------------------+----------+---------+------+-------------+--------+---------+-----+--------------------+------+--------+-----------------+---------+--------------------+------+-------------+--------------------+------+
# |              artist|      auth|firstName|gender|itemInSession|lastName|   length|level|            location|method|    page|     registration|sessionId|                song|status|           ts|           userAgent|userId|
# +--------------------+----------+---------+------+-------------+--------+---------+-----+--------------------+------+--------+-----------------+---------+--------------------+------+-------------+--------------------+------+
# |            Harmonia| Logged In|     Ryan|     M|            0|   Smith|655.77751| free|San Jose-Sunnyval...|   PUT|NextSong|1.541016707796E12|      583|       Sehr kosmisch|   200|1542241826796|"Mozilla/5.0 (X11...|    26|
# ...

# %%
from pyspark.sql import functions as F
import datetime
print(datetime.datetime.utcfromtimestamp(1542241826796/1000))
print(datetime.datetime.utcfromtimestamp(1542242481796/1000))
events_data.withColumn("time_stamp",F.to_timestamp(F.col("ts")/1000)).withColumn("day",F.day(F.col("time_stamp"))).show()
# events_data.rdd.map(lambda x: x["ts"]).collect()[:10]
# Out:
# 2018-11-15 00:30:26.796000
# 2018-11-15 00:41:21.796000
# +--------------------+----------+---------+------+-------------+--------+---------+-----+--------------------+------+--------+-----------------+---------+--------------------+------+-------------+--------------------+------+--------------------+---+
# |              artist|      auth|firstName|gender|itemInSession|lastName|   length|level|            location|method|    page|     registration|sessionId|                song|status|           ts|           userAgent|userId|          time_stamp|day|
# +--------------------+----------+---------+------+-------------+--------+---------+-----+--------------------+------+--------+-----------------+---------+--------------------+------+-------------+--------------------+------+--------------------+---+
# ...

# %%
#load songs_data
songs_data = spark.read\
    .json("/home/befawzy/projects/DE_nanodegree/data_warehousing/project/data/A/*")

# %%
songs_data.show()
# Out:
# +------------------+---------------+--------------------+----------------+--------------------+---------+---------+------------------+--------------------+----+
# |         artist_id|artist_latitude|     artist_location|artist_longitude|         artist_name| duration|num_songs|           song_id|               title|year|
# +------------------+---------------+--------------------+----------------+--------------------+---------+---------+------------------+--------------------+----+
# |ARTC1LV1187B9A4858|        51.4536|Goldsmith's Colle...|        -0.01802|  The Bonzo Dog Band|301.40036|        1|SOAFBCP12A8C13CC7D|King Of Scurf (20...|1972|
# |ARA23XO1187B9AF18F|       40.57885|Carteret, New Jersey|       -74.21956|     The Smithereens|  192.522|        1|SOKTJDS12AF72A25E5|Drown In My Own T...|   0|
# |ARSVTNL1187B992A91|       51.50632|     London, England|        -0.12714|       Jonathan King|129.85424|        1|SOEKAZG12AB018837E|I'll Slap Your Fa...|2001|
# ...

# %%
#construct user table

#extract user_id, first_name, last_name, gender, level from the staging events

# %%
#construct artist
